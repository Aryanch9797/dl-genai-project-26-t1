# %% [markdown]
# In this notebook we will calculate BPM for every audio file and save it in a CSV file so it can be used to generate data while training models.
# It will save a lot of time as we only have to compute bpm once.

# %%
from glob import glob
import librosa
import numpy as np
import pandas as pd
import os
from tqdm import tqdm

# %%
audio_files = glob("/kaggle/input/jan-2026-dl-gen-ai-project/messy_mashup/genres_stems/*/*/*.wav")

# %%
bpm_data = []

for path in tqdm(audio_files):
    audio , _ = audio , sr = librosa.load(path, sr=22050)
    onset_env = librosa.onset.onset_strength(y=audio, sr=22050) 
    current_bpm = librosa.feature.tempo(onset_envelope=onset_env)[0]
    if current_bpm <= 0: 
        current_bpm = 120.0
    bpm_data.append({
            "path": path,      
            "bpm": current_bpm  
        })

df = pd.DataFrame(bpm_data)
df.to_csv("bpm.csv",index=False)
# Out:
# 100%|██████████| 4000/4000 [16:57<00:00,  3.93it/s]

# %% [markdown]
# # Data Generator (Part 2 of 5)
#
# ## Objective
# This notebook utilizes `data_generator.py` to create mashups from the audio stems and store them as mel-spectrograms in the Kaggle output, which can be used later to train models.
#
# ## Workflow & Pipeline
# - We will create 10GB worth of data in each data_generator notebook.
# - There will be a total of 5 notebooks with the same code as this.
# - Data from 4 notebooks will be used for training, and 1 notebook will be used as validation.
# - We are using separate notebooks to prevent timeouts and storage issues.

# %% [markdown]
# # Import Libraries

# %%
import glob
import librosa
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import sys

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("github_access")
# !git clone https://{secret_value_0}@github.com/Aryanch9797/dl-genai-project-26-t1.git

repo_path = "/kaggle/working/dl-genai-project-26-t1"
if repo_path not in sys.path:
    sys.path.append(repo_path)

from src.Data_generator.data_generator import generate

# %% [markdown]
# # Defining paths

# %%
STEMS_DIR = "/kaggle/input/jan-2026-dl-gen-ai-project/messy_mashup/genres_stems"
NOISE_DIR = "/kaggle/input/jan-2026-dl-gen-ai-project/messy_mashup/ESC-50-master/audio/"
BPM_CSV = "/kaggle/input/notebooks/aryanchauhan97971234/bpm-calculator-ipynb/bpm.csv"

OUTPUT_DIR = "/kaggle/working/train_data"  # This will be saved as dataset
MAX_STORAGE_GB = 10  # creating mel spectogram untill we reach 10GB

SR = 16000   #sample_rate
DURATION = 10.24  # audio duration in seconds

GENRES = ["blues", "classical", "country", "disco", "hiphop",
          "jazz", "metal", "pop", "reggae", "rock"]

# %%
counts = generate(STEMS_DIR, NOISE_DIR, BPM_CSV, OUTPUT_DIR, GENRES, SR, MAX_STORAGE_GB)
print(f"Data generation complete \nTotal samples: {counts}")

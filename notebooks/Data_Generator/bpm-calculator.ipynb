# %% [markdown]
# # Audio Tempo Mapping: BPM Dictionary Generator

# %% [markdown]
# ## **Objective**
# This notebook utilizes `bpm_calculator.py` to extract the Beats Per Minute (BPM) from a dataset of audio files and compiles them into a mapping dictionary.
#
# ## **Use Case**
# When creating mashups from individual audio stems, we need to match their tempos accurately. Pre-computing and storing these BPM values in a dictionary significantly speeds up the mashup generation pipeline by eliminating the need to calculate tempos on the fly.

# %% [markdown]
# # Import Libraries

# %%
import glob
import librosa
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import sys

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("github_access")
# !git clone https://{secret_value_0}@github.com/Aryanch9797/dl-genai-project-26-t1.git

repo_path = "/kaggle/working/dl-genai-project-26-t1"
if repo_path not in sys.path:
    sys.path.append(repo_path)

from src.Data_generator.bpm_calculator import calculate_bpm
# Out:
# Cloning into 'dl-genai-project-26-t1'...
# remote: Enumerating objects: 165, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 165 (delta 14), reused 27 (delta 9), pack-reused 130 (from 1)
# Receiving objects: 100% (165/165), 64.40 MiB | 31.70 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
audio_path = "/kaggle/input/jan-2026-dl-gen-ai-project/messy_mashup/genres_stems/*/*/*.wav"
calculate_bpm(audio_path)
# Out:
# 100%|██████████| 4000/4000 [14:13<00:00,  4.68it/s]
